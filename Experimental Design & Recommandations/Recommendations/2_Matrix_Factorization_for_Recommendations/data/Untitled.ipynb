# %%
a = [1, 2, 3]

# %%
a.popleft()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-ed139145787f> in <module>()
# ----> 1 a.popleft()
#
# AttributeError: 'list' object has no attribute 'popleft'

# %%
[[1] + [2]]
# Out:
# [[1, 2]]
